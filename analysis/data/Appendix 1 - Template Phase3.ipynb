# %% [markdown]
# <img src="https://www.unad.edu.co/images/footer/logo-unad-acreditacion-min.png" width="780" height="140" align="right"/>

# %% [markdown]
# <p style="text-align: center;"> Course: Advanced Machine Learning</p>
#
# <p style="text-align: center;"> Course code: 203238427 </p>
#
# <p style="text-align: center;"> Group: __ </p>
#
# <p style="text-align: center;"> Phase 3 - Ensemble learning</p>
#
# <p style="text-align: center;">  Presented by: __________________</p>
#
# <p style="text-align: center;">  Tutor: _____________________________ </p>
#
# <p style="text-align: center;"> UNIVERSIDAD NACIONAL ABIERTA Y A DISTANCIA - UNAD </p>
#
# <p style="text-align: center;"> _______________</p>

# %% [markdown]
# # Load dataset

# %%
from sklearn.datasets import fetch_openml
dfr = fetch_openml(data_id=xxx, parser='auto') # Write in this space the id corresponding to the chosen item
dfc = fetch_openml(data_id=xxx, parser='auto')

# %% [markdown]
# # Exercise 1: Voting and Stacking.

# %% [markdown]
# # Exercise 2: Bagging.

# %% [markdown]
# # Exercise 3: Boosting.

# %% [markdown]
# # Exercise 4: Random Forest.

# %% [markdown]
# # References
